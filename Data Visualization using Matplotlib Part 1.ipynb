# %%
import matplotlib.pyplot as plt

# %%
x = [10, 20, 30, 35]
y = [20, 25, 35, 55]

# %%
plt.title("Linear graph 2D", fontsize = 25, color ="Green")
plt.plot(x, y)

# %%
plt.title("Linear graph", fontsize = 25, color ="Green")
plt.plot(x, y)
